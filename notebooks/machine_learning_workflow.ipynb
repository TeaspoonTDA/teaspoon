# %% [markdown]
# # Example Pipeline for Featurization and Machine Learning from Persistence Diagrams

# %%
from teaspoon.ML import load_datasets

# %%
shrec14 = load_datasets.shrec14()

# %%
shrec14
# Out:
#       freq  trial                                       CollectedDgm  \
# 1781   178      2  [[-2.0, 42.562, 265.34], [-2.0, 45.691, 265.34...
# 1766   176      7  [[-2.0, 5.2302, 18.017], [-2.0, 5.4308, 18.017...
# 2617   261      8  [[-2.0, 4.7516, 6.1081], [-2.0, 4.7699, 6.1081...
# 1778   177      9  [[-2.0, 2.0653, 4.1011], [-2.0, 2.0741, 4.1011...
# 1076   107      7  [[-2.0, 4.8845, 15.88], [-2.0, 5.0897, 15.88],...
# ...    ...    ...                                                ...
# 856     85      7  [[-2.0, 4.1233, 13.504], [-2.0, 4.234, 13.504]...
# 1461   146      2  [[-2.0, 37.777, 216.36], [-2.0, 41.236, 216.36...
# 573     57      4  [[-2.0, 15.591, 47.013], [-2.0, 15.673, 47.013...
# 2382   238      3  [[-2.0, 26.79, 107.12], [-2.0, 26.87, 107.12],...
# 2119   211     10  [[-2.0, 4.2785, 4.2787], [-2.0, 4.2785, 4.2787...
#
#                                                    Dgm1  \
# 1781  [[42.562, 265.34], [45.691, 265.34], [32.327, ...
# 1766  [[5.2302, 18.017], [5.4308, 18.017], [2.166, 1...
# 2617  [[4.7516, 6.1081], [4.7699, 6.1081], [4.4211, ...
# 1778  [[2.0653, 4.1011], [2.0741, 4.1011], [1.6765, ...
# 1076  [[4.8845, 15.88], [5.0897, 15.88], [1.9959, 12...
# ...                                                 ...
# 856   [[4.1233, 13.504], [4.234, 13.504], [1.7075, 1...
# 1461  [[37.777, 216.36], [41.236, 216.36], [33.347, ...
# 573   [[15.591, 47.013], [15.673, 47.013], [8.5575, ...
# 2382  [[26.79, 107.12], [26.87, 107.12], [14.474, 10...
# 2119  [[4.2785, 4.2787], [4.2785, 4.2787], [4.2785, ...
#
#                                                    Dgm0      TrainingLabel
# 1781  [[28.319, 265.34], [28.422, 38.477], [28.563, ...        female_thin
# 1766  [[2.1443, 18.017], [2.1443, 2.1444], [2.1445, ...        female_thin
# 2617  [[4.4199, 6.1081], [4.4199, 4.4199], [4.4199, ...         child_thin
# 1778  [[1.6738, 4.1011], [1.6743, 1.676], [1.6759, 1...        female_thin
# 1076  [[1.9727, 15.88], [1.9728, 1.973], [1.9728, 1....     female_neutral
# ...                                                 ...                ...
# 856                                  [[1.6681, 13.504]]       male_average
# 1461  [[24.967, 216.36], [25.144, 38.716], [26.111, ...         female_fat
# 573   [[7.5782, 47.013], [7.5782, 7.5805], [7.7325, ...           male_fat
# 2382  [[13.569, 107.12], [14.025, 17.523], [15.966, ...  child_bodybuilder
# 2119  [[4.2785, 4.2787], [4.2785, 4.2785], [4.2785, ...      child_neutral
#
# [3000 rows x 6 columns]
